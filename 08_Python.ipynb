# %% [markdown]
# # Ejercicio 1
# Desarrolle un programa en Python que muestre un menú repetitivo con las siguientes
# opciones:
# 1. Ingresar ventas de productos.
# 2. Mostrar reporte.
# 3. Salir.
# Al elegir la opción 1, el programa debe pedir cuántas ventas desea registrar y luego, usando
# un ciclo for, solicitar el monto de cada venta una por una. Cada monto ingresado debe
# validarse con captura de excepciones para evitar errores cuando el usuario escriba texto u
# otro valor inválido en lugar de un número.
# Durante el ingreso de ventas, el programa debe:
# * Acumular el total vendido.
# * Contar cuántas ventas fueron mayores a 10000.
# * Contar cuántas ventas fueron menores o iguales a 10000.|
# * Acumular por separado el total de ventas mayores a 10000 y el total de ventas
# menores o iguales a 10000.
# Al elegir la opción 2, el programa debe mostrar:
# Cantidad total de ventas registradas.
# * Monto total vendido.
# * Cantidad de ventas mayores a 10000.
# * Cantidad de ventas menores o iguales a 10000.
# * Promedio general de ventas, solo si se ingresó al menos una venta.
# * Promedio de las ventas mayores a 10000, solo si existe al menos una.
# * Promedio de las ventas menores o iguales a 10000, solo si existe al menos una.
# El menú debe repetirse con un ciclo while hasta que el usuario elija la opción 3. Si el usuario
# ingresa una opción inválida o escribe un dato no numérico en el menú, el programa debe
# capturar la excepción y mostrar un mensaje de error sin terminar abruptamente.

# %%
total_vendido = 0
cant_may_10 = 0
cant_men_10 = 0
total_may_10 = 0
total_men_10 = 0
cant_ventas = 0
avg_general =  0
avg_ventas_may_10 = 0
avg_ventas_men_10 = 0

while(True):
    opcion = int(input("""Seleccione una opción del Menu:
    1. Ingrese ventas de productos.
    2. Mostrar reporte.
    3. Salir
    > """))
    # La primera opcion debe decir Ingresar ventas de producto
    if opcion == 1:
        cant_ventas = int(input('Cuantas ventas quisiera registrar: '))

        for venta in range(0, cant_ventas):
            try:
                monto_vta = int(input('Ingrese el monto de cada venta : '))
                # Acumular el total vendido
                total_vendido += monto_vta
                # Cantidad de ventas mayores a 10000
                if monto_vta > 10000:
                    cant_may_10 += 1
                    # Total de ventas mayores a 10000
                    total_may_10 += monto_vta
                #Cantidad de ventas menores o iguales a 10000
                if monto_vta <= 10000:
                    cant_men_10 += 1
                    # Total de ventas menores e iguales a 10000
                    total_men_10 += monto_vta
                
            except ValueError:
                print('Error')

    elif opcion == 2:
        try:

            if total_vendido > 0 and cant_ventas > 0:
                avg_general =  total_vendido / cant_ventas  
            else:
                avg_general = 0

            if total_may_10 > 0 and cant_may_10 > 0:
                avg_ventas_may_10 = total_may_10 / cant_may_10
            else:
                avg_ventas_may_10 = 0 

            if total_men_10 > 0 and cant_men_10 > 0:
                avg_ventas_men_10 = total_men_10 / cant_men_10
            else:
                avg_ventas_men_10 = 0

        except ZeroDivisionError:
            print('EL numero no debe ser divisble por cero')

        print(f'Total de ventas mayores a $10.000.- CLP es de {total_may_10}')
        print(f'Total de ventas menores o iguales a $10.000.- CLP es de {total_men_10}')
        print(f'Cantidad de ventas mayores a $10.000.- CLP es de {cant_may_10}')
        print(f'Cantidad de ventas menores o iguales a $10.000.- CLP es de {cant_men_10}')
        print(f'Total de ventas {total_vendido}')
        print(f'Promedio general de ventas {avg_general}')
        print(f'Promedio de ventas mayores a $10.000.- {avg_ventas_may_10}')
        print(f'Promedio de ventas menores o iguales a $10.000.- {avg_ventas_men_10}')

    elif opcion == 3:
        print('Exit')
        break

# %% [markdown]
# # Ejercicio 2
# Desarrolle un programa en Python que presente un menú con estas opciones:
# * Registrar notas de estudiantes.
# * Mostrar estadísticas.
# * Salir.
# En la opción 1, el usuario debe indicar cuántas notas ingresará. Luego, mediante un ciclo
# for, el programa pedirá cada nota y deberá validar con excepciones que sea numérica.
# Considere notas entre 1.0 y 7.0; si se ingresa un valor fuera de rango, debe mostrarse un
# mensaje y no considerarse en los cálculos.
# El programa debe usar contadores y acumuladores para determinar:
# * Cantidad de notas aprobadas.
# * Cantidad de notas reprobadas.
# * Suma total de notas válidas.
# * Nota mayor ingresada.
# * Nota menor ingresada.
# En la opción 2, debe mostrar el total de notas válidas, el promedio general, la cantidad de
# aprobados y reprobados, y el porcentaje de aprobación. El menú debe mantenerse activo
# con while hasta seleccionar salir, controlando entradas inválidas con try y except

# %%
contador_aprobado = 0
contador_reprobado = 0
suma_notas = 0
total_notas = 0
Porcetaje_aprobacion= 0

while True:
    print("===== MENU PRINCIPAL DE NOTAS ESTUDIANTES =====")
    print("[1]- Rigistro de notas del estudiante.")
    print("[2]- Mostrar estadisticas del estudiante.")
    print("[3]- Salir de este menu de notas.")
    while True:
        try:
            opcion=int(input("Ingrese aqui la opcion que desea: "))
            if opcion != 1 and opcion != 2 and opcion != 3:
                print("Las opciones deben encajar con el menu principal.")
            
        except:
            print("La opcion ingresada debe ser de solo numeros.")
        
        if opcion == 1:
            cantidad_notas=int(input("Ingrese aqui la cantidad de notas que desea: "))
            for i in range (0,cantidad_notas):
                while True:
                    try:
                        notas=float(input(f"Ingese las notas que posee {i+1}:"))
                        if notas < 1.0:
                            print("deben ser notas entre 1.0 a 7.0")
                        elif notas > 7.0:
                            print("deben ser notas entre 1.0 a 7.0")
                            continue
                        if  notas >= 4.0:
                            contador_aprobado+=1
                        elif notas :
                            contador_reprobado+=1

                            suma_notas+=notas
                        break
                    except:
                        print("deben ser solo numeros.")
    
                                
        elif opcion == 2:
            total_notas=len(cantidad_notas) 
        if notas == 0:
            print("no hay notas ingresadas vuelva a la primera opcion.")
        else:
            tota_de_notas = sum(notas)
            promedio = tota_de_notas / total_notas

            nota_mayor= max(notas)
            nota_menor= min(notas)
            Porcetaje_aprobacion= contador_aprobado / tota_de_notas *100

        print("===== AQUI PUEDES VER TUS ESTADISTICAS =====")
        print(tota_de_notas)
        print()
        print()
        print()
        print()
        print()
        print()
        print()

# %% [markdown]
# # Ejercicio 3
# Desarrolle un programa en Python para un gimnasio que muestre un menú con las
# siguientes opciones:
# *. Registrar días de entrenamiento.
# *. Ver resumen.
# *. Salir.
# En la opción 1, el usuario indicará cuántos días desea registrar. Luego, usando un ciclo for,
# en cada día deberá ingresar la cantidad de minutos entrenados. El programa debe validar
# con manejo de excepciones que el dato ingresado sea entero positivo.
# Durante el proceso, el programa debe:
# * Acumular el total de minutos entrenados.
# * Contar cuántos días entrenó 60 minutos o más.
# * Contar cuántos días entrenó menos de 60 minutos.
# * Acumular por separado los minutos de ambos grupos.
# En la opción 2, se debe mostrar la cantidad de días registrados, el total de minutos, el
# promedio de minutos por día y los contadores de días según su duración. El menú debe
# repetirse con while hasta que el usuario seleccione salir, y toda entrada inválida debe
# manejarse con captura de excepciones.

# %%
mayor_60minutos= 0
menor_60minutos= 0
total_minutos = 0
opcion = 0 

while True:
    print("==== Bienvenido a su menu de jercicios ====")
    print("(1) - Registra tus dias de entrenamiento.")
    print("(2) - Resumen de tus dias de entrenamiento.")
    print("(3) - Salir de este menu.")
    while True:
        try:
            opcion=int(input("Digite aqui que opcion desea: "))
            if opcion < 1 or opcion > 5:
                print("Opcion invalida, deben ser solo las disponiblesss en el menu.")
        except:
            print("Deben ser solo numeros enteros.")
        if opcion == 1:
            while True:
                try:
                    resgistro_dias=int(input("ingrese aqui los dias que desea entrenar: "))
                    if resgistro_dias <= 0:
                        print("Los dias deben ser mayores a 0")
                except:
                    print(" solo deben ser numeros enteros.")
                for i in range (0,resgistro_dias):
                    minutos_ejercicio=int(input(f"ingrese aqui los minutos que desea por dia {i+1}: "))
                    if minutos_ejercicio <= 0:
                        print("Los minutos no pueden ser cero minutos por dia")
                    minutos_ejercicio=int(input(f"ingrese aqui los minutos que desea por dia {i+1}: "))
                    if minutos_ejercicio <= 0:
                        print("Los minutos no pueden ser cero minutos por dia")

# %% [markdown]
#  # Ejercicio 4
# Desarrolle un programa en Python que simule el control de consumo de agua de una
# vivienda mediante un menú con estas opciones:
# * Registrar consumo mensual.
# * Mostrar informe.
# * Salir.
# E la opción 1, el programa debe pedir cuántos meses desea registrar. Luego, con un ciclo
# for, solicitará los litros consumidos en cada mes. Debe usar try y except para controlar
# errores de ingreso y aceptar solo números positivos.
# El programa debe trabajar con:
# * Un acumulador para el consumo total.
# * Un contador para meses con consumo superior a 15000 litros.
# * Un contador para meses con consumo menor o igual a 15000 litros.
# * Acumuladores separados para ambos tipos de consumo.
# En la opción 2, deberá mostrar el total consumido, el promedio mensual, cuántos meses
# superaron el límite indicado y cuántos no. El menú debe mantenerse en ejecución con while
# hasta la opción de salida.
